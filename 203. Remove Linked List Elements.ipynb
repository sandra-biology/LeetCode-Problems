# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

# %%
head = None

node = ListNode(6)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(6)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 1
# node.val = 2
# node.val = 6
# node.val = 3
# node.val = 4
# node.val = 5
# node.val = 6

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:
        node = head
        while node:
            if node.val == val:
                # remove the node
                node = node.next
            else:
                node = node.next

        return head

##  -------------------- main-------------------------------
solution = Solution()

head = None

node = ListNode(6)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(6)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

val = 6
res = solution.removeElements(head, val)

node = res
while node:
    print(f"after removing:\nnode.val = {node.val}")
    node = node.next
# Out:
# after removing:
# node.val = 1
# after removing:
# node.val = 2
# after removing:
# node.val = 6
# after removing:
# node.val = 3
# after removing:
# node.val = 4
# after removing:
# node.val = 5
# after removing:
# node.val = 6

# %%
# code works for all cases except where the node to be deleted is the only one in the list and the one head is pointing to

class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:
        if head == None:
            return head
        
        node = head
        while node.next:
            if node.next.val == val:
                # remove the node
                node.next = node.next.next
            else:
                node = node.next

        return head

##  -------------------- main-------------------------------
solution = Solution()

head = None

node = ListNode(1)
node.next = head
head = node

print("before removing:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

val = 1
res = solution.removeElements(head, val)

print("\nafter removing:")
node = res
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# before removing:
# node.val = 1
#
# after removing:
# node.val = 1

# %%
head = None

node = ListNode(1)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 1

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:        
        node = head
        prev = None
        while node:
            if node.val == val:
                # remove the node
                if prev:
                    prev.next = node.next
                    # prev itself stays the same
                    node = node.next
                else:
                    # this is the first node
                    head = node.next
            else:
                prev = node
                node = node.next

        return head

##  -------------------- main-------------------------------
solution = Solution()

head = None

node = ListNode(6)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(6)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

val = 6
res = solution.removeElements(head, val)

node = res
while node:
    print(f"after removing:\nnode.val = {node.val}")
    node = node.next
# Out:
# after removing:
# node.val = 1
# after removing:
# node.val = 2
# after removing:
# node.val = 3
# after removing:
# node.val = 4
# after removing:
# node.val = 5

# %% [markdown]
# ### First submission
#
# Accepted by LeetCode: Runtime: 56 ms, faster than 99.29% of Python3 online submissions for Remove Linked List Elements.
# Memory Usage: 16.9 MB, less than 5.55% of Python3 online submissions for Remove Linked List Elements.

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:        
        node = head
        prev = None
        
        while node:
            if node.val == val:
                # remove the node
                if prev:
                    prev.next = node.next
                    # prev itself stays the same
                    node = node.next
                else:
                    # this is the first node
                    head = node.next
                    node = head
            else:
                prev = node
                node = node.next

        return head

##  -------------------- main-------------------------------
solution = Solution()

head = None

node = ListNode(1)
node.next = head
head = node

val = 1
res = solution.removeElements(head, val)

node = res
while node:
    print(f"after removing:\nnode.val = {node.val}")
    node = node.next
