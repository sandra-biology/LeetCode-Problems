# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def isPalindrome(self, head: ListNode) -> bool:
        pass

# %%
lst = [1, 2, 2, 1]
print(lst == lst[::-1])
# Out:
# True

# %%
head = None

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 1
# node.val = 2
# node.val = 2
# node.val = 1

# %%
list_array = []

node = head
while node:
    list_array.append(node.val)
    node = node.next

print(f"list_array = {list_array}")
print(list_array == list_array[::-1])
# Out:
# list_array = [1, 2, 2, 1]
# True

# %% [markdown]
# ### First submission
# Appending values of nodes to array
#
# Accepted by LeetCode: Runtime: 64 ms, faster than 91.68% of Python3 online submissions for Palindrome Linked List.
# Memory Usage: 24 MB, less than 15.38% of Python3 online submissions for Palindrome Linked List.

# %%
def palindrome(head):
    list_array = []
    node = head
    while node:
        list_array.append(node.val)
        node = node.next
    return list_array == list_array[::-1]

palindrome(head)
# Out:
# True

# %%
count = 0
node = head
while node:
    count += 1
    node = node.next
print(count)

# n_max = count

node = head
for i in range(count // 2):
    pass

for node in range(n1):
    node = node.next
val_left = node.val

for node in range(n2):
    node = node.next
val_right = node.val

if val_left == val_right:
    print(True)
else:
    print(False)
# Out:
# 4

# %%
head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print(f"My list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

print(f"\n---------------------\n")
    
count = 0
node = head
while node:
    count += 1
    node = node.next
print(f"count: {count}")

node1 = head
for i1 in range(count // 2):
    # print(f"node1.val = {node1.val}")
    n1 = i1
    n2 = count - n1 - 1
    # the number of jumps
    njumps = n2 - n1
    
    # get the node with index n2
    node2 = node1
    for i2 in range(njumps):
        node2 = node2.next
        
    print(f"-- node1.val: {node1.val}, node2.val: {node2.val}")
    
    node1 = node1.next
# Out:
# My list:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 30
# node.val = 20
# node.val = 10
#
# ---------------------
#
# count: 6
# -- node1.val: 10, node2.val: 10
# -- node1.val: 20, node2.val: 20
# -- node1.val: 30, node2.val: 30

# %%
head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print(f"My list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

print(f"\n---------------------\n")
    
count = 0
node = head
while node:
    count += 1
    node = node.next
print(f"count: {count} nodes in the list")

odd_offset = count % 2
print(f"odd_offset: {odd_offset}")

node1 = head
for i1 in range(count // 2):
    # print(f"node1.val = {node1.val}")
    n1 = i1
    n2 = count - n1 - 1
    # the number of jumps
    njumps = n2 - n1
    print(f"n1: {n1}, n2: {n2}, njumps: {njumps}")
    
    # get the node with index n2
    node2 = node1
    for i2 in range(njumps):
        node2 = node2.next

    print(f"-- node1.val: {node1.val}, node2.val: {node2.val}")
    
    node1 = node1.next
# Out:
# My list:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 30
# node.val = 20
# node.val = 10
#
# ---------------------
#
# count: 7 nodes in the list
# odd_offset: 1
# n1: 0, n2: 6, njumps: 6
# -- node1.val: 10, node2.val: 10
# n1: 1, n2: 5, njumps: 4
# -- node1.val: 20, node2.val: 20
# n1: 2, n2: 4, njumps: 2
# -- node1.val: 30, node2.val: 30

# %%
# works.

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print(f"My list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

print(f"\n---------------------\n")
    
count = 0
node = head
while node:
    count += 1
    node = node.next
print(f"count: {count} nodes in the list")

node1 = head
for i1 in range(count // 2):
    # print(f"node1.val = {node1.val}")
    n1 = i1
    n2 = count - n1 - 1
    # the number of jumps
    njumps = n2 - n1
    print(f"n1: {n1}, n2: {n2}, njumps: {njumps}")
    
    # get the node with index n2
    node2 = node1
    for i2 in range(njumps):
        node2 = node2.next

    print(f"-- node1.val: {node1.val}, node2.val: {node2.val}")
    
    if node1.val != node2.val:
        print("list is not a palindrome")
    
    node1 = node1.next
# Out:
# My list:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 30
# node.val = 20
# node.val = 10
#
# ---------------------
#
# count: 7 nodes in the list
# n1: 0, n2: 6, njumps: 6
# -- node1.val: 10, node2.val: 10
# list is a palindrome
# n1: 1, n2: 5, njumps: 4
# -- node1.val: 20, node2.val: 20
# list is a palindrome
# n1: 2, n2: 4, njumps: 2
# -- node1.val: 30, node2.val: 30
# list is a palindrome

# %% [markdown]
# ### Brute force algorithm
#
# Exceeds time limit as expected

# %%
# works.
def isPalindrome(head):
    count = 0
    node = head
    while node:
        count += 1
        node = node.next

    node1 = head
    for i1 in range(count // 2):
        n1 = i1
        n2 = count - n1 - 1
        njumps = n2 - n1

        # get the node with index n2
        node2 = node1
        for i2 in range(njumps):
            node2 = node2.next

        if node1.val != node2.val:
            return False

        node1 = node1.next

    return True


# ------------------------main---------------------------------------------
head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

# print(f"My list:")
# node = head
# while node:
#     print(f"node.val = {node.val}")
#     node = node.next

isPalindrome(head)
# Out:
# True

# %%
head = None

node = ListNode(11)
node.next = head
head = node

node = ListNode(21)
node.next = head
head = node

node = ListNode(31)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("before reversing second half of list")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

# approach: reverse second half of list:
# two pointers: node_fast and node_slow
head1 = head
node_fast = head1
node_slow = head1
head2 = head1
count = 0
while node_fast:
    head2 = node_fast
    node_fast = node_fast.next
    if count > 0 and count % 2 == 0:
        node_slow = node_slow.next
    count += 1

# at this point, node_slow has reached midpoint of the list
print(f"head2.val: {head2.val}, node_slow.val: {node_slow.val}")

# reverse the right part
head3 = node_slow.next
curr = head3
prev = None
next = curr
print(f"before while: curr.val = {curr.val}, next.val = {next.val}")
while curr:
    head3 = curr
    next = curr.next
    curr.next = prev
    
    prev = curr
    curr = next
    

print("after reversing")
node = head3
while node:
    print(f"node.val = {node.val}")
    node = node.next
# then compare nodes in the first half of the list with nodes in the second half of the list

# what the first half looks like
print("checking what the first half of list looks like")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# before reversing second half of list
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 31
# node.val = 21
# node.val = 11
# head2.val: 11, node_slow.val: 40
# before while: curr.val = 31, next.val = 31
# after reversing
# node.val = 11
# node.val = 21
# node.val = 31
# checking what the first half of list looks like
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 31

# %%
# approach: reverse second half of list: # worked on first attempt
# two pointers: node_fast and node_slow

def palindrome(head):
    head1 = head
    node_fast = head1
    node_slow = head1
    head2 = head1
    count = 0
    while node_fast:
        head2 = node_fast
        node_fast = node_fast.next
        if count > 0 and count % 2 == 0:
            node_slow = node_slow.next
        count += 1

    # last = node_slow
    # if count % 2 == 0:
    #     node_slow = node_slow.next

    # at this point, node_slow has reached midpoint of the list
# print(f"head2.val: {head2.val}, node_slow.val: {node_slow.val}, count: {count}")

    # reverse the right part
    head3 = node_slow.next
    curr = head3
    prev = None
    next = curr
    # print(f"before while: curr.val = {curr.val}, next.val = {next.val}")
    while curr:
        head3 = curr
        next = curr.next
        curr.next = prev

        prev = curr
        curr = next
    

    # print("after reversing")
    node = head3
    while node:
        # print(f"node.val = {node.val}")
        node = node.next
    # then compare nodes in the first half of the list with nodes in the second half of the list

# # what the first half looks like
# print("checking what the first half of list looks like")
# node = head
# while node:
#     print(f"node.val = {node.val}")
#     node = node.next
    # comparing two halves, going through the second half of the list
    node1 = head1
    node3 = head3
    while node1 and node3:
        if node1.val == node3.val:
            node1 = node1.next
            node3 = node3.next
            return True
        else:
            node1 = node1.next
            node3 = node3.next
            return False
        
# --------------------main--------------------------
head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

# node = ListNode(40)
# node.next = head
# head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

palindrome(head)
# Out:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 30
# node.val = 20
# node.val = 10
# True

# %%
# approach: reverse second half of list:
# two pointers: node_fast and node_slow

def palindrome(head):
    if head == None:
        return True
    
    head1 = head
    node_fast = head1
    node_slow = head1
    head2 = head1
    count = 0
    while node_fast:
        head2 = node_fast
        node_fast = node_fast.next
        if count > 0 and count % 2 == 0:
            node_slow = node_slow.next
        count += 1
    
    if count < 2:
        return True
    # at this point, node_slow has reached midpoint of the list
    # reverse the right part
    head3 = node_slow.next
    curr = head3
    prev = None
    next = curr
    while curr:
        head3 = curr
        next = curr.next
        curr.next = prev

        prev = curr
        curr = next
    

    node = head3
    while node:
        node = node.next
    # comparing two halves, going through the second half of the list
    node1 = head1
    node3 = head3
    while node1 and node3:
        if node1.val == node3.val:
            node1 = node1.next
            node3 = node3.next
            return True
        else:
            node1 = node1.next
            node3 = node3.next
            return False
        
# --------------------main--------------------------
head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

# node = ListNode(40)
# node.next = head
# head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

palindrome(head)
# Out:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 30
# node.val = 20
# node.val = 10
# True

# %%
# approach: reverse second half of list: # worked on first attempt
# two pointers: node_fast and node_slow

def palindrome(head):
    head1 = head
    node_fast = head1
    node_slow = head1
    head2 = head1
    count = 0
    while node_fast:
        head2 = node_fast
        node_fast = node_fast.next
        if count > 0 and count % 2 == 0:
            node_slow = node_slow.next
        count += 1

    # last = node_slow
    # if count % 2 == 0:
    #     node_slow = node_slow.next

    # at this point, node_slow has reached midpoint of the list
    print(f"head2.val: {head2.val}, node_slow.val: {node_slow.val}, count: {count}")

    # reverse the right part
    head3 = node_slow.next
    curr = head3
    prev = None
    next = curr
    print(f"before while: curr.val = {curr.val}, next.val = {next.val}")
    while curr:
        head3 = curr
        next = curr.next
        curr.next = prev

        prev = curr
        curr = next
    
    print()
    print("after reversing")
    node = head3
    while node:
        print(f"node.val = {node.val}")
        node = node.next

    # comparing two halves, going through the second half of the list
    node1 = head1
    node3 = head3
    while node3:
        print(f"node1.val = {node1.val}, node3.val = {node3.val}")
        if node1.val == node3.val:
            node1 = node1.next
            node3 = node3.next
        else:
            node1 = node1.next
            node3 = node3.next
            return False
    
    return True

head = None

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = head

while node:
    print(f"node.val = {node.val}")
    node = node.next
print()
palindrome(head)
# Out:
# node.val = 1
# node.val = 1
# node.val = 2
# node.val = 1
#
# head2.val: 1, node_slow.val: 1, count: 4
# before while: curr.val = 2, next.val = 2
#
# after reversing
# node.val = 1
# node.val = 2
# node1.val = 1, node3.val = 1
# node1.val = 1, node3.val = 2
# False

# %%
def palindrome(head):
    head1 = head
    node_fast = head1
    node_slow = head1
    head2 = head1
    count = 0
    while node_fast:
        head2 = node_fast
        node_fast = node_fast.next
        if count > 0 and count % 2 == 0:
            node_slow = node_slow.next
        count += 1

    # last = node_slow
    # if count % 2 == 0:
    #     node_slow = node_slow.next

    # at this point, node_slow has reached midpoint of the list
    print(f"head2.val: {head2.val}, node_slow.val: {node_slow.val}, count: {count}")

    # reverse the right part
    head3 = node_slow.next
    curr = head3
    prev = None
    next = curr
    print(f"before while: curr.val = {curr.val}, next.val = {next.val}")
    while curr:
        head3 = curr
        next = curr.next
        curr.next = prev

        prev = curr
        curr = next
    
    print()
    print("after reversing")
    node = head3
    while node:
        print(f"node.val = {node.val}")
        node = node.next

    # comparing two halves, going through the second half of the list
    node1 = head1
    node3 = head3
    while node3:
        print(f"node1.val = {node1.val}, node3.val = {node3.val}")
        if node1.val == node3.val:
            node1 = node1.next
            node3 = node3.next
        else:
            node1 = node1.next
            node3 = node3.next
            return False
    
    return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

palindrome(head)
# Out:
# head2.val: 10, node_slow.val: 40, count: 7
# before while: curr.val = 30, next.val = 30
#
# after reversing
# node.val = 10
# node.val = 20
# node.val = 30
# node1.val = 10, node3.val = 10
# node1.val = 20, node3.val = 20
# node1.val = 30, node3.val = 30
# True

# %% [markdown]
# ### Submission
#
# Accepted by LeetCode: Runtime: 80 ms, faster than 21.42% of Python3 online submissions for Palindrome Linked List.
# Memory Usage: 24 MB, less than 15.38% of Python3 online submissions for Palindrome Linked List.

# %%
class Solution:
    def palindrome(self, head):
        if head == None:
            return True
        
        head1 = head
        node_fast = head1
        node_slow = head1
        head2 = head1
        count = 0
        while node_fast:
            head2 = node_fast
            node_fast = node_fast.next
            if count > 0 and count % 2 == 0:
                node_slow = node_slow.next
            count += 1

        # reverse the right part
        head3 = node_slow.next
        curr = head3
        prev = None
        next = curr
        while curr:
            head3 = curr
            next = curr.next
            curr.next = prev

            prev = curr
            curr = next

        node = head3
        while node:
            node = node.next

        # comparing two halves, going through the second half of the list
        node1 = head1
        node3 = head3
        while node3:
            if node1.val == node3.val:
                node1 = node1.next
                node3 = node3.next
            else:
                return False

        return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

solution = Solution()
solution.palindrome(head)
# Out:
# True

# %% [markdown]
# Approach: reverse first half of list as we're going through the list

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("before reversing the first half")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

         
# trying to reverse the first half of list
head1 = head
node_fast = head1
node_slow = head1
head2 = head1
count = 0
while node_fast:
    head2 = node_fast
    node_fast = node_fast.next
    if count > 0 and count % 2 == 0:
        node_slow = node_slow.next
    count += 1
    print(f"node_fast.val = {node_fast.val}, count = {count}, node_slow.val = {node_slow.val}")    
    
    head1 = node_slow
    curr = head1
    prev = None
    next = None
    while curr:
        head1 = curr
        next = curr.next
        
        prev = curr
        curr = next

print("after reversing")
node = head1
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# before reversing the first half
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 30
# node.val = 20
# node.val = 10
# node_fast.val = 20, count = 1, node_slow.val = 10
# node_fast.val = 30, count = 2, node_slow.val = 10
# node_fast.val = 40, count = 3, node_slow.val = 20
# node_fast.val = 30, count = 4, node_slow.val = 20
# node_fast.val = 20, count = 5, node_slow.val = 30
# node_fast.val = 10, count = 6, node_slow.val = 30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-37b5e8fc8411> in <module>()
#      53         node_slow = node_slow.next
#      54     count += 1
# ---> 55     print(f"node_fast.val = {node_fast.val}, count = {count}, node_slow.val = {node_slow.val}")
#      56
#      57     head1 = node_slow
#
# AttributeError: 'NoneType' object has no attribute 'val'

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

# node = ListNode(40)
# node.next = head
# head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("before reversing the first half")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

         
# trying to reverse the first half of list
head1 = head
node_fast = head1
node_slow = head1
head2 = head1
count = 0
while node_fast:
    head2 = node_fast
    node_fast = node_fast.next
    if count > 0 and count % 2 == 0:
        node_slow = node_slow.next
        head1 = node_slow
        curr = head1
        prev = None
        next = None
        head1 = curr
        next = curr.next
        
        prev = curr
        curr = next
    count += 1
    # print(f"node_fast.val = {node_fast.val}, count = {count}, node_slow.val = {node_slow.val}")    
    
    # head1 = node_slow
    # curr = head1
    # prev = None
    # next = None
    # while curr:
        # head1 = curr
        # next = curr.next
        
        # prev = curr
        # curr = next

print("after reversing")
node = head1
while node:
    print(f"node.val = {node.val}")
    node = node.next

# loop over second half of list
head2 = node_slow.next
node2 = head2
node1 = head
while node2: 
    if node2.val == node1.val:
        print("palindrome")
    else:
        print("not a palindrome")
# Out:
# before reversing the first half
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 30
# node.val = 20
# node.val = 10
# after reversing
# node.val = 30
# node.val = 30
# node.val = 20
# node.val = 10

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None



print("before reversing the first half")
def palindrome(head):
    node = head
    while node:
        print(f"node.val = {node.val}")
        node = node.next


    # trying to reverse the first half of list
    head1 = head
    node_fast = head1
    node_slow = head1
    head2 = head1
    count = 0
    while node_fast:
        node_fast = node_fast.next
        if count > 0 and count % 2 == 0:
            head2 = node_slow.next
            node_slow = node_slow.next
            head1 = node_slow
            curr = head1.next
            prev = None
            next = None
            
            head1 = curr
            next = curr.next

            prev = curr
            curr = next
        count += 1

    print("after reversing")
    node1 = head1
    while node1:
        print(f"node1.val = {node1.val}")
        node1 = node1.next
    print()
    node2 = head2.next
    if count % 2:
        head2 = head2.next
    while node2:
        print(f"node2.val = {node2.val}")
        node2 = node2.next

    # loop over second half of list
    node2 = head2
    node1 = head1
    while node1: 
        if node2.val == node1.val:
            node1 = node1.next
            node2 = node2.next
        else:
            return False

    return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

palindrome(head)
# Out:
# before reversing the first half
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 30
# node.val = 20
# node.val = 10
# after reversing
# node1.val = 30
# node1.val = 20
# node1.val = 10
#
# node2.val = 30
# node2.val = 20
# node2.val = 10
# True

# %%
# working solution, takes care of there being 2 nodes in the list with another if statement
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        node = head
        while node:
            print(f"node.val = {node.val}")
            node = node.next


        # trying to reverse the first half of list
        head1 = head
        node_fast = head1
        node_slow = head1
        head2 = head1
        count = 0
        while node_fast:
            node_fast = node_fast.next
            if count > 0 and count % 2 == 0:
                head2 = node_slow.next  # ?
                node_slow = node_slow.next
                head1 = node_slow
                curr = head1.next
                prev = None
                next = None

                head1 = curr
                next = curr.next

                prev = curr
                curr = next
            count += 1
        
        if count < 2:
            return True
        
        if count == 2:
            return head1.val == head2.val

        head2 = head2.next
        # if count %2:
        #     head2 = head2.next

        print("after reversing")
        node1 = head1
        while node1:
            print(f"node1.val = {node1.val}")
            node1 = node1.next

        print()

        node2 = head2
        while node2:
            print(f"node2.val = {node2.val}")
            node2 = node2.next

        # loop over second half of list
        node2 = head2
        node1 = head1
        while node1: 
            if node2.val == node1.val:
                node1 = node1.next
                node2 = node2.next
            else:
                return False

        return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 30
# node.val = 20
# node.val = 10
# after reversing
# node1.val = 30
# node1.val = 20
# node1.val = 10
#
# node2.val = 30
# node2.val = 20
# node2.val = 10
# True

# %%
# jupyter continues to give wrong answer for this list (even though function body has not changed)
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        # node = head
        # while node:
        #     print(f"node.val = {node.val}")
        #     node = node.next


        # trying to reverse the first half of list
        head1 = head
        node_fast = head1
        node_slow = head1
        head2 = head1
        count = 0
        while node_fast:
            count += 1
            node_fast = node_fast.next
            if count % 2 == 0:
                head2 = node_slow.next  # ?
                node_slow = node_slow.next
                head1 = node_slow
                curr = head1.next
                prev = None
                next = None

                head1 = curr
                next = curr.next

                prev = curr
                curr = next

        if count < 2:
            return True
        
        if count == 2:
            return head1.val == head2.val

        head2 = head2.next
        # if count %2:
        #     head2 = head2.next

        print("after reversing")
        node1 = head1
        while node1:
            print(f"node1.val = {node1.val}")
            node1 = node1.next

        print()

        node2 = head2
        while node2:
            print(f"node2.val = {node2.val}")
            node2 = node2.next

        # loop over second half of list
        node2 = head2
        node1 = head1
        while node1: 
            if node2.val == node1.val:
                node1 = node1.next
                node2 = node2.next
            else:
                return False

        return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(31)
node.next = head
head = node

node = ListNode(21)
node.next = head
head = node

node = ListNode(11)
node.next = head
head = node

# print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# after reversing
# node1.val = 30
# node1.val = 20
# node1.val = 10
#
# node2.val = 30
# node2.val = 20
# node2.val = 10
# True

# %%
# working solution, takes care of there being 2 nodes in the list with another if statement
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        node = head
        while node:
            print(f"node.val = {node.val}")
            node = node.next
        
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                print(f"   node_slow.val: {node_slow.val}")
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
                print(f"  node_slow.val: {node_slow.val}, prev.val: {prev.val}, next.val: {next.val}")
            count += 1

        head1 = prev
        head2 = next
        
        print(f"count: {count}, head1.val: {head1.val}, head2.val: {head2.val}")
        
        print("after reversing first half")
        node1 = head1
        while node1:
            print(f"node1.val = {node1.val}")
            node1 = node1.next
            
        node2 = head2
        while node2:
            print(f"node2.val = {node2.val}")
            node2 = node2.next
        
        
        
        
        
        
        return True

head = None

node = ListNode(11)
node.next = head
head = node

node = ListNode(21)
node.next = head
head = node

node = ListNode(31)
node.next = head
head = node

# node = ListNode(40)
# node.next = head
# head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 31
# node.val = 21
# node.val = 11
#    node_slow.val: 10
#   node_slow.val: 20, prev.val: 10, next.val: 20
#    node_slow.val: 20
#   node_slow.val: 30, prev.val: 20, next.val: 30
#    node_slow.val: 30
#   node_slow.val: 31, prev.val: 30, next.val: 31
# count: 6, head1.val: 30, head2.val: 31
# after reversing first half
# node1.val = 30
# node1.val = 20
# node1.val = 10
# node2.val = 31
# node2.val = 21
# node2.val = 11
# True

# %%
# working solution, takes care of there being 2 nodes in the list with another if statement
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        node = head
        while node:
            print(f"node.val = {node.val}")
            node = node.next
        
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                print(f"   node_slow.val: {node_slow.val}")
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
                print(f"  node_slow.val: {node_slow.val}, prev.val: {prev.val}, next.val: {next.val}")
            count += 1

        head1 = prev
        head2 = next
        if count % 2:
            head2 = head2.next # the central node along is equal to ifself
        
        print(f"count: {count}, head1.val: {head1.val}, head2.val: {head2.val}")
        
        print("after reversing first half")
        node1 = head1
        while node1:
            print(f"node1.val = {node1.val}")
            node1 = node1.next
            
        node2 = head2
        while node2:
            print(f"node2.val = {node2.val}")
            node2 = node2.next
        
        node1 = head1
        node2 = head2
        while node2:
            if node1.val == node2.val:
                node1 = node1.next
                node2 = node2.next
            else:
                return False
        
        return True

head = None

node = ListNode(11)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

# node = ListNode(40)
# node.next = head
# head = node

# node = ListNode(30)
# node.next = head
# head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 20
# node.val = 11
#    node_slow.val: 10
#   node_slow.val: 20, prev.val: 10, next.val: 20
#    node_slow.val: 20
#   node_slow.val: 30, prev.val: 20, next.val: 30
# count: 5, head1.val: 20, head2.val: 20
# after reversing first half
# node1.val = 20
# node1.val = 10
# node2.val = 20
# node2.val = 11
# False

# %%
# working solution, takes care of there being 2 nodes in the list with another if statement
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        node = head
        while node:
            print(f"node.val = {node.val}")
            node = node.next
        
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                print(f"   node_slow.val: {node_slow.val}")
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
                print(f"  node_slow.val: {node_slow.val}, prev.val: {prev.val}, next.val: {next.val}")
            count += 1

        head1 = prev
        head2 = next
        if count % 2:
            head2 = head2.next
        
        print(f"count: {count}, head1.val: {head1.val}, head2.val: {head2.val}")
        
        print("after reversing first half")
        node1 = head1
        while node1:
            print(f"node1.val = {node1.val}")
            node1 = node1.next
            
        node2 = head2
        while node2:
            print(f"node2.val = {node2.val}")
            node2 = node2.next
        
        
        
        
        
        
        return True

head = None

node = ListNode(11)
node.next = head
head = node

node = ListNode(21)
node.next = head
head = node

node = ListNode(31)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 31
# node.val = 21
# node.val = 11
#    node_slow.val: 10
#   node_slow.val: 20, prev.val: 10, next.val: 20
#    node_slow.val: 20
#   node_slow.val: 30, prev.val: 20, next.val: 30
#    node_slow.val: 30
#   node_slow.val: 40, prev.val: 30, next.val: 40
# count: 7, head1.val: 30, head2.val: 31
# after reversing first half
# node1.val = 30
# node1.val = 20
# node1.val = 10
# node2.val = 31
# node2.val = 21
# node2.val = 11
# True

# %% [markdown]
# ### Second submission
#
# Accepted by LeetCode: Runtime: 64 ms, faster than 91.94% of Python3 online submissions for Palindrome Linked List.
# Memory Usage: 24 MB, less than 15.38% of Python3 online submissions for Palindrome Linked List.

# %%
# solution works, final form for LeetCode
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
            count += 1
        
        if count == 1:
            return True

        head1 = prev
        head2 = next
        if count % 2:
            head2 = head2.next # the central node along is equal to ifself
        
        node1 = head1
        node2 = head2
        while node2:
            if node1.val == node2.val:
                node1 = node1.next
                node2 = node2.next
            else:
                return False
        
        return True

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

# print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# True

# %% [markdown]
# ### Third Submission
#
# Accepted by LeetCode: Runtime: 72 ms, faster than 59.00% of Python3 online submissions for Palindrome Linked List.
# Memory Usage: 23.7 MB, less than 73.08% of Python3 online submissions for Palindrome Linked List.

# %%
# solution works
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
            count += 1
        
        if count == 1:
            return True

        head1 = prev
        head2 = next
        
        is_palindrome = True
        
        node1 = head1
        node2 = head2
        if count % 2:
            node2 = node2.next # skip the lone central node
        while node2:
            if node1.val == node2.val:
                node1 = node1.next
                node2 = node2.next
            else:
                is_palindrome = False
                break
        
        return is_palindrome

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

# print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# True

# %%
# solution works
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:

    def isPalindrome(self, head):
        if not head:
            return True

        node_fast = head
        node_slow = head
        prev = None
        next = head.next  # NB: needs at least 1 node in the list
        count = 0

        while node_fast:
            node_fast = node_fast.next  # increment node_fast at each node

            if count % 2:
                next = node_slow.next
                node_slow.next = prev
                prev = node_slow
                node_slow = next  # increment node_slow at each other node
            count += 1
        
        if count == 1:
            return True

        head1 = prev
        head2 = next
        
        is_palindrome = True
        
        node1 = head1
        node2 = head2
        if count % 2:
            node2 = node2.next # skip the lone central node
        while node2:
            if node1.val == node2.val:
                node1 = node1.next
                node2 = node2.next
            else:
                is_palindrome = False
                break
        
        return is_palindrome

head = None

node = ListNode(10)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(40)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

# print("original list")

solution = Solution()
solution.isPalindrome(head)
# Out:
# True

# %%
count = 7
count % 2 # True
# Out:
# 1
