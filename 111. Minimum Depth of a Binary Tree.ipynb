# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def minDepth(self, root: TreeNode) -> int:
        pass

# %%
# use in order traversal or other depth traversal method separately for left_subtree and for right_subtree
# return separate values for minimum depth for each sub_tree
# function returns minimum of the two values

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def breadth_first_level(self, root):
        queue = deque([root])
        list_node_values = []
        
        while queue:
            level = []
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    level.append(node.val)
                    queue.append(node.left)
                    queue.append(node.right)

            list_node_values.append(level)
        
        return list_node_values[:-1]
          
    # when we find the first node without children, stop
    def min_depth(self, root):
        if root is None:
            return 0

        queue = deque([root])
        depth = 0
        
        while queue:
            depth += 1
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    queue.append(node.left)
                    queue.append(node.right)

            if node.left is None and node.right is None:
                break
        
        return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

solution = Solution()
print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution.min_depth(root)
# Out:
# bread-first traversal = [[3], [9, 20], [15, 7]]
# 3

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def breadth_first_level(self, root):
        queue = deque([root])
        list_node_values = []
        
        while queue:
            level = []
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    level.append(node.val)
                    queue.append(node.left)
                    queue.append(node.right)

            list_node_values.append(level)
        
        return list_node_values[:-1]
          
    # when we find the first node without children, stop
    def min_depth(self, root):
        if root is None:
            return 0

        queue = deque([root])
        depth = 0
        
        while queue:
            depth += 1
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    queue.append(node.left)
                    queue.append(node.right)

            print(f"queue = {queue}")
            # loop over current level, if a node doesn't have children, return depth
            for node in queue:
                if node.left is None and node.right is None:
                    return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

solution = Solution()
print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution.min_depth(root)
# Out:
# bread-first traversal = [[3], [9, 20], [15, 7]]
# queue = deque([<__main__.TreeNode object at 0x00000239A9EF6860>, <__main__.TreeNode object at 0x00000239A9F069B0>])
# 1

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def breadth_first_level(self, root):
        queue = deque([root])
        list_node_values = []
        
        while queue:
            level = []
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    level.append(node.val)
                    queue.append(node.left)
                    queue.append(node.right)

            list_node_values.append(level)
        
        return list_node_values[:-1]
          
    # when we find the first node without children, stop
    def min_depth(self, root):
        if root is None:
            return 0

        queue = deque([root])
        depth = 1
        
        while queue:
            n = len(queue)
            print(f"n = {n}")
            
            for i in range(n):
                node = queue.popleft()
                if node is None:
                    return depth
                else:
                    queue.append(node.left)
                    queue.append(node.right)

#             print(f"queue = {queue}")
#             # loop over current level, if a node doesn't have children, return depth
#             for node in queue:
#                 if node.left is None and node.right is None:
#                     return depth
            depth += 1
        print(f"depth = {depth}")

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

solution = Solution()
print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution.min_depth(root)
# Out:
# bread-first traversal = [[3], [9, 20], [15, 7]]
# n = 1
# n = 2
# n = 4
# 3

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def breadth_first_level(self, root):
        queue = deque([root])
        list_node_values = []
        
        while queue:
            level = []
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                if node:
                    level.append(node.val)
                    queue.append(node.left)
                    queue.append(node.right)

            list_node_values.append(level)
        
        return list_node_values[:-1]
          
    # when we find the first node without children, stop
    def min_depth(self, root):
        if root is None:
            return 0
        
        queue = deque([root])
        depth = 1
        
        while queue:
            # here queue contains nodes only from previous level
            n = len(queue)
            
            for i in range(n):
                node = queue.popleft()
                print(f"node.val = {node.val}")
                if node.left is None and node.right is None:
                    return depth
                else:
                    queue.append(node.left)
                    queue.append(node.right)
                # here queue contains nodes only from current level

#             print(f"queue = {queue}")
#             # loop over current level, if a node doesn't have children, return depth
#             for node in queue:
#                 if node.left is None and node.right is None:
#                     return depth
            depth += 1
        print(f"depth = {depth}")
        return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

solution = Solution()
print(f"bread-first traversal = {solution.breadth_first_level(root)}")
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# bread-first traversal = [[3], [9, 20], [15, 7]]
# node.val = 3
# node.val = 9
# depth = 2

# %%
def min_depth(root):
    if root is None:
        return 0

    depth = 1
    queue = deque([root])
    
    while queue:
        # queue contains nodes from previous level only
        node = queue.popleft()
        if node.left is None and node.right is None:
            return depth

        else:
            queue.append(node.left)
            queue.append(node.right)

        # queue contains nodes from previous level and from current level
        depth += 1
    
    print(f"depth = {depth}")
    return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
depth = min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 2

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(root):
        if root is None:
            return 0

        depth = 1
        queue = deque([root])

        while queue:
            # queue contains nodes from previous level only
            node = queue.popleft()
            if node.left is None and node.right is None:
                return depth

            else:
                queue.append(node.left)
                queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        print(f"depth = {depth}")
        return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 2

# %%
# works for trees where root has both left child and right child
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                node = queue.popleft()
                if node is None:
                    return depth

                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        print(f"depth = {depth}")
        return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 2

# %%
# working solution for trees with root that is missing either child
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        if root.left is None or root.right is None:
            return 2

        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                node = queue.popleft()
                if node is None:
                    return depth

                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        print(f"depth = {depth}")
        return depth

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

# root = TreeNode(1)
# root.left = TreeNode(2)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 2

# %%
# for LeetCode
# solution that works for trees with root that is missing either child but not when both children are missing
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        # if root.left is None or root.right is None:  # commented out because this gives the wrong answer
        #     return 2

        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                node = queue.popleft()
                if node is None:
                    return depth

                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        return depth

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 2

# %%
# for LeetCode
# working on solution for trees with root that is missing both children
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        # if root.left is None or root.right is None:  # commented out because this gives the wrong answer
        #     return 2

        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                node = queue.popleft()
                if node is None:
                    return depth
                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        return depth

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

# root = TreeNode(1)
# root.left = TreeNode(2)

root = TreeNode(1)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# depth = 1

# %%
# for LeetCode - gives wrong answer
# working on solution for trees with root that is missing both children
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        # if root.left is None or root.right is None:  # commented out because this gives the wrong answer
        #     return 2

        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                print(f"n = {n}")
                node = queue.popleft()
                if node is None:
                    return depth
                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        return depth

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)

# root = TreeNode(1)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# n = 1
# n = 2
# n = 2
# depth = 1

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 1
        queue = deque([root])
        while queue:
            node = queue.popleft()
            if node.left is None and node.right is None:
                return depth
            
            if node.left is not None:
                queue.append(node.left)
            if node.right is not None:
                queue.append(node.right)
            depth += 1
        
        return depth

# root = TreeNode(1)
# root.left = TreeNode(2)

# root = TreeNode(0)

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

solution = Solution()
solution.min_depth(root)
# Out:
# 2

# %%
# mechanism: return depth when we find a leaf node (node with no children)

from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 1
        queue = deque([root])
        while queue:
            node = queue.popleft()
            if node.left is None and node.right is None:
                return depth
            
            if node.left is not None:
                queue.append(node.left)
            if node.right is not None:
                queue.append(node.right)
            depth += 1
        
        return depth

# root = TreeNode(1)
# root.left = TreeNode(2)

# root = TreeNode(0)

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

solution = Solution()
solution.min_depth(root)
# Out:
# 3

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 0
        queue = deque([root])

        while queue: 
            # queue contains nodes from previous level only
            n = len(queue)
            for i in range(n):
                print(f"n = {n}")
                node = queue.popleft()
                if node is None:
                    return depth
                else:
                    queue.append(node.left)
                    queue.append(node.right)

            # queue contains nodes from previous level and from current level
            depth += 1

        return depth

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)

# root = TreeNode(1)

# print(f"bread-first traversal = {solution.breadth_first_level(root)}")
solution = Solution()
depth = solution.min_depth(root)
print(f"depth = {depth}")
# Out:
# n = 1
# n = 2
# n = 2
# depth = 1

# %%
# mechanism: return depth when we find a leaf node (node with no children), initializing depth and root in dictionary

from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 1
        queue = [{'node': root, 'depth': depth}]
        while queue:
            popped_element = queue.pop(0)
            print(f"type(popped_element) = {type(popped_element)}")
            node = popped_element['node']
            depth = popped_element['depth']
            
            if node.left is None and node.right is None:
                return depth
            
            if node.left is not None:
                queue.append({'node': node.left, 'depth': depth+1})
            if node.right is not None:
                queue.append({'node': node.right, 'depth': depth+1})
        
        return depth

# root = TreeNode(1)
# root.left = TreeNode(2)

# root = TreeNode(0)

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

solution = Solution()
solution.min_depth(root)
# Out:
# type(popped_element) = <class 'dict'>
# type(popped_element) = <class 'dict'>
# type(popped_element) = <class 'dict'>
# 2

# %% [markdown]
# ### First submission
#
# Accepted by LeetCode: Runtime: 84 ms, faster than 5.70% of Python3 online submissions for Minimum Depth of Binary Tree.
# Memory Usage: 15 MB, less than 62.16% of Python3 online submissions for Minimum Depth of Binary Tree.

# %%
# mechanism: return depth when we find a leaf node (node with no children), initializing depth and root in dictionary
# for LeetCode

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        depth = 1
        queue = [{'node': root, 'depth': depth}]
        while queue:
            popped_element = queue.pop(0)
            node = popped_element['node']
            depth = popped_element['depth']
            
            if node.left is None and node.right is None:
                return depth
            
            if node.left is not None:
                queue.append({'node': node.left, 'depth': depth+1})
            if node.right is not None:
                queue.append({'node': node.right, 'depth': depth+1})
        
        return depth

# root = TreeNode(1)
# root.left = TreeNode(2)

# root = TreeNode(0)

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

solution = Solution()
solution.min_depth(root)
# Out:
# 2

# %%
# algorithm from Geeks for geeks

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def min_depth(self, root):
        if root is None:
            return 0
        
        queue = []
        queue.append({'node': root , 'depth' : 1})
        while queue:
            popped = queue.pop(0)
            node = popped['node']
            depth = popped['depth']
            
            if node.left is None and node.right is None:
                return depth
            
            if node.left is not None:
                queue.append({"node": node.left, "depth": depth+1})
            if node.right is not None:
                queue.append({"node": node.right, "depth": depth+1})
            # depth += 1
        
        return depth

# root = TreeNode(1)
# root.left = TreeNode(2)

# root = TreeNode(0)

# root = TreeNode(3)
# root.left = TreeNode(9)
# root.right = TreeNode(20)
# root.right.left = TreeNode(15)
# root.right.right = TreeNode(7)

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

solution = Solution()
solution.min_depth(root)
# Out:
# type(popped) = <class 'dict'>
# type(popped) = <class 'dict'>
# type(popped) = <class 'dict'>
# 2
