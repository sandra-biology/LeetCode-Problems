# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

head = None

node = ListNode(70)
node.next = head
head = node

node = ListNode(60)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node
node30 = node

node = ListNode(50)
node.next = head
head = node
node50 = node  # end of sorted part

node = ListNode(40)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 40
# node.val = 50
# node.val = 30
# node.val = 60
# node.val = 70

# %%
def insert_list(head, end):
    node = head
    while node:
        print(f"node.val = {node.val}")
        if node == end:
            break
        node = node.next
    if end.next:
        print(f"end.next.val = {end.next.val}")

insert_list(head, node50)
# Out:
# node.val = 10
# node.val = 20
# node.val = 40
# node.val = 50
# end.next.val = 30

# %%
def insert_list(head, end):
    sel = end.next
    if not sel:
        return
    end.next = sel.next

insert_list(head, node50)

# %%
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 10
# node.val = 20
# node.val = 40
# node.val = 50
# node.val = 60
# node.val = 70

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

head = None

node = ListNode(70)
node.next = head
head = node

node = ListNode(60)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node
node30 = node

node = ListNode(50)
node.next = head
head = node
node50 = node  # end of sorted part

node = ListNode(40)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

print("original list")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list
# node.val = 10
# node.val = 20
# node.val = 40
# node.val = 50
# node.val = 30
# node.val = 60
# node.val = 70

# %%
def insert_list(head, end):
    sel = end.next
    print(f"sel.val = {sel.val}")
    prev = head
    curr = head
    if not sel:
        return
    end.next = sel.next # remove sel from list
    while curr:
        print(f"curr.val = {curr.val}, sel.val = {sel.val}, prev.val = {prev.val}")
        if sel.val < curr.val:
            sel.next = curr
            prev.next = sel
        curr = curr.next
    return head

res = insert_list(head, node50)
# Out:
# sel.val = 30
# curr.val = 10, sel.val = 30, prev.val = 10
# curr.val = 20, sel.val = 30, prev.val = 10
# curr.val = 40, sel.val = 30, prev.val = 10
# curr.val = 50, sel.val = 30, prev.val = 10
# curr.val = 60, sel.val = 30, prev.val = 10
# curr.val = 70, sel.val = 30, prev.val = 10

# %%
def insert_list(head, end):
    """
    Takes sorted part of linked list. Moves next node in the linked list to appropriate position in sorted part
    of linked list.
    """
    sel = end.next
    print(f"sel.val = {sel.val}")
    if not sel:
        return

#    end.next = sel.next # remove sel from list
    prev = None
    curr = head
    while curr:
        print(f"curr.val = {curr.val}, sel.val = {sel.val}")
        if sel.val < curr.val:
            end.next = sel.next  # remove sel from list
            sel.next = curr
            if prev:
                prev.next = sel
            else:
                sel.next = head
                head = sel
            break
        if curr == end:
            break
        prev = curr
        curr = curr.next
    return head

res = insert_list(head, node50)
# Out:
# sel.val = 30
# curr.val = 10, sel.val = 30
# curr.val = 20, sel.val = 30
# curr.val = 40, sel.val = 30

# %%
def insert_list(head, end):
    """
    Takes sorted part of linked list. Moves next node in the linked list to appropriate position in sorted part
    of linked list.
    """
    sel = end.next
    if not sel:
        return

    curr = head
    prev = None
    while curr:
        if sel.val < curr.val:
            end.next = sel.next  # remove sel from list
            sel.next = curr
            if prev:
                prev.next = sel
            else:
                sel.next = head
                head = sel
            break
        if curr == end:
            break
        prev = curr
        curr = curr.next
    return head

def insertion_sort_list(head):
    node = head
    while node:
        insert_list(head, node)
        node = node.next
    return head

# res = insert_list(head, node50)
res = insertion_sort_list(head)

node = res
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 50
# node.val = 60
# node.val = 70

# %%
node = res
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# node.val = 10
# node.val = 20
# node.val = 30
# node.val = 40
# node.val = 50
# node.val = 60
# node.val = 70

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def insert_list(self, head, end):
        sel = end.next
        if not sel:
            return

        curr = head
        prev = None
        while curr:
            if sel.val < curr.val:
                end.next = sel.next  # remove sel from list
                sel.next = curr
                if prev:
                    prev.next = sel
                else:
                    sel.next = head
                    head = sel
                break
            if curr == end:
                break
            prev = curr
            curr = curr.next
        return head

    def insertionSortList(self, head: ListNode) -> ListNode:
        node = head
        while node:
            self.insert_list(head, node)
            node = node.next
        return head

head = None

node = ListNode(70)
node.next = head
head = node

node = ListNode(60)
node.next = head
head = node

node = ListNode(30)
node.next = head
head = node
node30 = node

node = ListNode(50)
node.next = head
head = node
node50 = node  # end of sorted part

node = ListNode(40)
node.next = head
head = node

node = ListNode(20)
node.next = head
head = node

node = ListNode(10)
node.next = head
head = node

solution = Solution()
res = solution.insertionSortList(head)

node1 = res
while node1:
    print(f"node1.val = {node1.val}")
    node1 = node1.next
# Out:
# node1.val = 10
# node1.val = 20
# node1.val = 30
# node1.val = 40
# node1.val = 50
# node1.val = 60
# node1.val = 70

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insert_list(head, end):
    """
    Inserts node end.next to the already sorted list from head to end.
    """
    
    print(f"\ninsert_list: head.val: {head.val}", end=" ")
    if end:
        print(f"end.val: {end.val}")
    
    to_sort = end.next
    if to_sort is None:
        return

    print(f"\n-- insert_list: start from head.val: {head.val}")
    curr = head
    prev = None
    while curr:
        print(f"to_sort.val: {to_sort.val}, curr.val: {curr.val}")
        if to_sort.val < curr.val:
            end.next = to_sort.next  # remove to_sort from list
            to_sort.next = curr
            if prev:
                prev.next = to_sort
            else:
                # insert node before head
                to_sort.next = head
                head = to_sort
                print(f".. insert before head: now head.val: {head.val}, head.next.val: {head.next.val}")
            # break  # job done: to_sort was inserted in the proper position
            return head  # job done: to_sort was inserted in the proper position

        print("  'else' branch: to_sort.val > curr.val. Before increment curr")

        if curr == end:
            break

        print("  'else' branch: to_sort.val > curr.val. Increment curr")

        prev = curr
        curr = curr.next
    return head

def insertionSortList(head):
    end = head
    while end:
        next = end.next
        print(f"\ncall insert_list({head.val}, {end.val})")
        head = insert_list(head, end)
        end = next
    return head

head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

# res = insertionSortList(head)

head_new = head
end = head_new
head_new = insert_list(head_new, end)

print(f"end.val: {end.val}")

head_new = insert_list(head_new, end)

res = head_new

print("\nsorted list:")
node_res = res
while node_res:
    print(f"node_res.val = {node_res.val}")
    node_res = node_res.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
#
# insert_list: head.val: 4 end.val: 4
#
# -- insert_list: start from head.val: 4
# to_sort.val: 2, curr.val: 4
# .. insert before head: now head.val: 2, head.next.val: 4
# end.val: 4
#
# insert_list: head.val: 2 end.val: 4
#
# -- insert_list: start from head.val: 2
# to_sort.val: 1, curr.val: 2
# .. insert before head: now head.val: 1, head.next.val: 2
#
# sorted list:
# node_res.val = 1
# node_res.val = 2
# node_res.val = 4
# node_res.val = 3

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insert_list(head, end):
    """
    Inserts node end.next to the already sorted list from head to end.
    """
    
    print(f"\ninsert_list: head.val: {head.val}", end=" ")
    if end:
        print(f", end.val: {end.val}")
    else:
        print(f", end is None")
    
    to_sort = end.next
    if to_sort is None:
        return

    print(f"\n-- insert_list: start from head.val: {head.val}")
    curr = head
    prev = None
    while curr:
        print(f"to_sort.val: {to_sort.val}, curr.val: {curr.val}")
        if to_sort.val < curr.val:
            end.next = to_sort.next  # remove to_sort from list
            to_sort.next = curr
            if prev:
                prev.next = to_sort
            else:
                # insert node before head
                to_sort.next = head
                head = to_sort
                print(f".. insert before head: now head.val: {head.val}, head.next.val: {head.next.val}")
            # break  # job done: to_sort was inserted in the proper position
            return head, end  # job done: to_sort was inserted in the proper position

        print("  'else' branch: to_sort.val > curr.val. Before increment curr")

        if curr == end:
            break

        print("  'else' branch: to_sort.val > curr.val. Increment curr")

        prev = curr
        curr = curr.next
    return head, end

def insertionSortList(head):
    end = head
    while end:
        # print(f"\ncall insert_list({head.val}, {end.val})")
        head, end = insert_list(head, end)
        
        if end.next:
            print(f"end.next.val: {end.next.val}")
        else:
            print(f"end.next is None")
        
        node = head
        while node:
            print(f"\tnode.val: {node.val}")
            node = node.next
        
        if end.next is None:
            return head
    return head

head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

res = insertionSortList(head)

# head_new = head
# end = head_new
# head_new, end = insert_list(head_new, end)

# if end:
#     print(f"end.val: {end.val}")

# head_new, end = insert_list(head_new, end)

# res = head_new

print("\nsorted list:")
node_res = res
while node_res:
    print(f"node_res.val = {node_res.val}")
    node_res = node_res.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
#
# insert_list: head.val: 4 , end.val: 4
#
# -- insert_list: start from head.val: 4
# to_sort.val: 2, curr.val: 4
# .. insert before head: now head.val: 2, head.next.val: 4
# end.next.val: 1
# 	node.val: 2
# 	node.val: 4
# 	node.val: 1
# 	node.val: 3
#
# insert_list: head.val: 2 , end.val: 4
#
# -- insert_list: start from head.val: 2
# to_sort.val: 1, curr.val: 2
# .. insert before head: now head.val: 1, head.next.val: 2
# end.next.val: 3
# 	node.val: 1
# 	node.val: 2
# 	node.val: 4
# 	node.val: 3
#
# insert_list: head.val: 1 , end.val: 4
#
# -- insert_list: start from head.val: 1
# to_sort.val: 3, curr.val: 1
#   'else' branch: to_sort.val > curr.val. Before increment curr
#   'else' branch: to_sort.val > curr.val. Increment curr
# to_sort.val: 3, curr.val: 2
#   'else' branch: to_sort.val > curr.val. Before increment curr
#   'else' branch: to_sort.val > curr.val. Increment curr
# ...

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insert_list(head, end):
    """
    Inserts node end.next to the already sorted list from head to end.
    """
    
    print(f"\ninsert_list: head.val: {head.val}", end=" ")
    if end:
        print(f", end.val: {end.val}")
    else:
        print(f", end is None")
    
    if end.next:
        print(f"insert_list: end.next is not None")
    else:
        print(f"insert_list: end.next is None")
        return head, None

    to_sort = end.next
    if to_sort is None:
        return

    print(f"\n-- insert_list: start from head.val: {head.val}")
    curr = head
    prev = None
    while curr:
        print(f"to_sort.val: {to_sort.val}, curr.val: {curr.val}")
        if to_sort.val < curr.val:
            end.next = to_sort.next  # remove to_sort from list
            to_sort.next = curr
            if prev:
                prev.next = to_sort
            else:
                # insert node before head
                to_sort.next = head
                head = to_sort
                print(f".. insert before head: now head.val: {head.val}, head.next.val: {head.next.val}")
            # break  # job done: to_sort was inserted in the proper position
            return head, end  # job done: to_sort was inserted in the proper position

        print("  'else' branch: to_sort.val > curr.val. Before increment curr")

        if curr == end:
            break

        print("  'else' branch: to_sort.val > curr.val. Increment curr")

        prev = curr
        curr = curr.next
    return head, end

def insertionSortList(head):
    end = head
    # while end and end.next:
    while end:
        print(f"\ncall insert_list({head.val}, {end.val})")
        head, end = insert_list(head, end)
        
        if end:
            if end.next:
                print(f"end.next.val: {end.next.val}")
            else:
                print(f"end.next is None")
        else:
            print(f"--> end is None")
        
        node = head
        while node:
            print(f"\tnode.val: {node.val}")
            node = node.next
        
        # if end.next is None:
        #     return head
    return head

head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

res = insertionSortList(head)

# head_new = head
# end = head_new
# head_new, end = insert_list(head_new, end)

# if end:
#     print(f"end.val: {end.val}")

# head_new, end = insert_list(head_new, end)

# res = head_new

print("\nsorted list:")
node_res = res
while node_res:
    print(f"node_res.val = {node_res.val}")
    node_res = node_res.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
#
# call insert_list(4, 4)
#
# insert_list: head.val: 4 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 4
# to_sort.val: 2, curr.val: 4
# .. insert before head: now head.val: 2, head.next.val: 4
# end.next.val: 1
# 	node.val: 2
# 	node.val: 4
# 	node.val: 1
# 	node.val: 3
#
# call insert_list(2, 4)
#
# insert_list: head.val: 2 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 2
# to_sort.val: 1, curr.val: 2
# .. insert before head: now head.val: 1, head.next.val: 2
# end.next.val: 3
# 	node.val: 1
# 	node.val: 2
# 	node.val: 4
# 	node.val: 3
#
# call insert_list(1, 4)
#
# insert_list: head.val: 1 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 1
# to_sort.val: 3, curr.val: 1
#   'else' branch: to_sort.val > curr.val. Before increment curr
# ...

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insert_list(head, end):
    """
    Inserts node end.next to the already sorted list from head to end.
    """
    
    print(f"\ninsert_list: head.val: {head.val}", end=" ")
    if end:
        print(f", end.val: {end.val}")
    else:
        print(f", end is None")
    
    if end.next:
        print(f"insert_list: end.next is not None")
    else:
        print(f"insert_list: end.next is None")
        ####### return head, None
    
    if head is None:
        return None, None
    
    if end is None:
        print(f"--> insert_list: end is None")
        return head, None

    to_sort = end.next  # the element to insert into sorted part
    if to_sort is None:
        print(f"--> insert_list: presumably the main return: to_sort is None")
        return head, None

    print(f"\n-- insert_list: start from head.val: {head.val}")
    curr = head
    prev = None
    while curr:
        print(f"to_sort.val: {to_sort.val}, curr.val: {curr.val}")
        if to_sort.val < curr.val:
            end.next = to_sort.next  # remove to_sort from list
            to_sort.next = curr
            if prev:
                prev.next = to_sort
            else:
                # insert node before head
                to_sort.next = head
                head = to_sort
                print(f".. insert before head: now head.val: {head.val}, head.next.val: {head.next.val}")
            # break  # job done: to_sort was inserted in the proper position
            return head, end  # job done: to_sort was inserted in the proper position

        print("  'else' branch: to_sort.val > curr.val. Before increment curr")

        if curr == end:
            break

        print("  'else' branch: to_sort.val > curr.val. Increment curr")

        prev = curr
        curr = curr.next
    return head, end

def insertionSortList(head):
    end = head
    while end:
        # print(f"\ncall insert_list({head.val}, {end.val})")

        head, end = insert_list(head, end)
        
        # if end:
        #     if end.next:
        #         print(f"end.next.val: {end.next.val}")
        #     else:
        #         print(f"end.next is None")
        # else:
        #     print(f"--> end is None")
        
        node = head
        while node:
            print(f"\tnode.val: {node.val}")
            node = node.next
    return head

head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

res = insertionSortList(head)

# head_new = head
# end = head_new
# head_new, end = insert_list(head_new, end)

# if end:
#     print(f"end.val: {end.val}")

# head_new, end = insert_list(head_new, end)

# res = head_new

print("\nsorted list:")
node_res = res
while node_res:
    print(f"node_res.val = {node_res.val}")
    node_res = node_res.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
#
# insert_list: head.val: 4 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 4
# to_sort.val: 2, curr.val: 4
# .. insert before head: now head.val: 2, head.next.val: 4
# 	node.val: 2
# 	node.val: 4
# 	node.val: 1
# 	node.val: 3
#
# insert_list: head.val: 2 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 2
# to_sort.val: 1, curr.val: 2
# .. insert before head: now head.val: 1, head.next.val: 2
# 	node.val: 1
# 	node.val: 2
# 	node.val: 4
# 	node.val: 3
#
# insert_list: head.val: 1 , end.val: 4
# insert_list: end.next is not None
#
# -- insert_list: start from head.val: 1
# to_sort.val: 3, curr.val: 1
#   'else' branch: to_sort.val > curr.val. Before increment curr
#   'else' branch: to_sort.val > curr.val. Increment curr
# to_sort.val: 3, curr.val: 2
#   'else' branch: to_sort.val > curr.val. Before increment curr
# ...

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insertion_sort_list(head):
    """
    Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
    Returns head of sorted list.
    """
    end = head
    while end:
        to_sort = end.next
        if to_sort is None:
            return head
        
        if to_sort.val >= end.val:
            end = to_sort
            print(f"move end: end.val: {end.val}")
            continue
        
        else:
            # end stays the same: to_sort moves down
            
            print(f"end stays the same: end.val: {end.val}")
            end.next = to_sort.next  # remove to_sort from the list

            curr = head
            prev = None
            while curr:
                print(f"\n\t-- to_sort.val: {to_sort.val}, curr.val: {curr.val}")
                if to_sort.val < curr.val:
                    if prev:
                        print(f"\tprev.val: {prev.val}")
                        to_sort.next = curr
                        prev.next = to_sort
                    else:
                        # insert before head
                        to_sort.next = head
                        head = to_sort
                        print(f"\tchange head: new head.val: {head.val}, head.next.val: {head.next.val}")
                        break  # job done
                prev = curr
                curr = curr.next
    
    return head
            
head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

head_sort = insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 2, curr.val: 4
# 	change head: new head.val: 2, head.next.val: 4
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 1, curr.val: 2
# 	change head: new head.val: 1, head.next.val: 2
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 3, curr.val: 1
#
# 	-- to_sort.val: 3, curr.val: 2
#
# 	-- to_sort.val: 3, curr.val: 4
# 	prev.val: 2
#
# sorted list:
# node.val = 1
# node.val = 2
# node.val = 3
# node.val = 4

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def insertion_sort_list(head):
    """
    Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
    Returns head of sorted list.
    """
    end = head
    while end:
        to_sort = end.next
        if to_sort is None:
            return head
        
        if to_sort.val >= end.val:
            end = to_sort
            print(f"move end: end.val: {end.val}")
            continue
        else:
            # end stays the same: to_sort moves down
            
            print(f"end stays the same: end.val: {end.val}")
            end.next = to_sort.next  # remove to_sort from the list

            curr = head
            prev = None
            while curr:
                print(f"\n\t-- to_sort.val: {to_sort.val}, curr.val: {curr.val}")
                if to_sort.val < curr.val:
                    if prev:
                        print(f"\tprev.val: {prev.val}")
                        to_sort.next = curr
                        prev.next = to_sort
                    else:
                        # insert before head
                        to_sort.next = head
                        head = to_sort
                        print(f"\tchange head: new head.val: {head.val}, head.next.val: {head.next.val}")
                    break  # job done
                prev = curr
                curr = curr.next
    
    return head
            
head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

head_sort = insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 2, curr.val: 4
# 	change head: new head.val: 2, head.next.val: 4
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 1, curr.val: 2
# 	change head: new head.val: 1, head.next.val: 2
# end stays the same: end.val: 4
#
# 	-- to_sort.val: 3, curr.val: 1
#
# 	-- to_sort.val: 3, curr.val: 2
#
# 	-- to_sort.val: 3, curr.val: 4
# 	prev.val: 2
#
# sorted list:
# node.val = 1
# node.val = 2
# node.val = 3
# node.val = 4

# %%
def insertion_sort_list(head):
    """
    Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
    Returns head of sorted list.
    """
    end = head
    while end:
        to_sort = end.next
        if to_sort is None:
            return head
        
        if to_sort.val >= end.val:
            end = to_sort
            print(f"move end: end.val: {end.val}")
            continue
        
        else:
            # end stays the same: to_sort moves down
            
            print(f"end stays the same: end.val: {end.val}")
            end.next = to_sort.next  # remove to_sort from the list

            curr = head
            prev = None
            while curr:
                print(f"\n\t-- to_sort.val: {to_sort.val}, curr.val: {curr.val}")
                if to_sort.val < curr.val:
                    # found place to insert. Insert and break.
                    if prev:
                        print(f"\tprev.val: {prev.val}")
                        to_sort.next = curr
                        prev.next = to_sort
                    else:
                        # insert before head
                        to_sort.next = head
                        head = to_sort
                        print(f"\tchange head: new head.val: {head.val}, head.next.val: {head.next.val}")
                    break  # job done
                prev = curr
                curr = curr.next
    
    return head
            
head = None

node = ListNode(0)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(-1)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

head_sort = insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = -1
# node.val = 5
# node.val = 3
# node.val = 4
# node.val = 0
# move end: end.val: 5
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 3, curr.val: -1
#
# 	-- to_sort.val: 3, curr.val: 5
# 	prev.val: -1
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 4, curr.val: -1
#
# 	-- to_sort.val: 4, curr.val: 3
#
# 	-- to_sort.val: 4, curr.val: 5
# 	prev.val: 3
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 0, curr.val: -1
#
# 	-- to_sort.val: 0, curr.val: 3
# 	prev.val: -1
#
# sorted list:
# node.val = -1
# node.val = 0
# node.val = 3
# node.val = 4
# node.val = 5

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def insertion_sort_list(self, head):
        """
        Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
        Returns head of sorted list.
        """
        end = head
        while end:
            to_sort = end.next
            if to_sort is None:
                return head

            if to_sort.val >= end.val:
                end = to_sort
                print(f"move end: end.val: {end.val}")
                continue

            else:
                # end stays the same: to_sort moves down

                print(f"end stays the same: end.val: {end.val}")
                end.next = to_sort.next  # remove to_sort from the list

                curr = head
                prev = None
                while curr:
                    print(f"\n\t-- to_sort.val: {to_sort.val}, curr.val: {curr.val}")
                    if to_sort.val < curr.val:
                        # found place to insert. Insert and break.
                        if prev:
                            print(f"\tprev.val: {prev.val}")
                            to_sort.next = curr
                            prev.next = to_sort
                        else:
                            # insert before head
                            to_sort.next = head
                            head = to_sort
                            print(f"\tchange head: new head.val: {head.val}, head.next.val: {head.next.val}")
                        break  # job done
                    prev = curr
                    curr = curr.next

        return head
            
head = None

node = ListNode(0)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(-1)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

solution = Solution()
head_sort = solution.insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = -1
# node.val = 5
# node.val = 3
# node.val = 4
# node.val = 0
# move end: end.val: 5
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 3, curr.val: -1
#
# 	-- to_sort.val: 3, curr.val: 5
# 	prev.val: -1
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 4, curr.val: -1
#
# 	-- to_sort.val: 4, curr.val: 3
#
# 	-- to_sort.val: 4, curr.val: 5
# 	prev.val: 3
# end stays the same: end.val: 5
#
# 	-- to_sort.val: 0, curr.val: -1
#
# 	-- to_sort.val: 0, curr.val: 3
# 	prev.val: -1
#
# sorted list:
# node.val = -1
# node.val = 0
# node.val = 3
# node.val = 4
# node.val = 5

# %%
# for LeetCode

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def insertion_sort_list(self, head):
        """
        Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
        Returns head of sorted list.
        """
        end = head
        while end:
            to_sort = end.next
            if to_sort is None:
                return head

            if to_sort.val >= end.val:
                end = to_sort
                continue

            else:
                # end stays the same: to_sort moves down

                end.next = to_sort.next  # remove to_sort from the list

                curr = head
                prev = None
                while curr:
                    if to_sort.val < curr.val:
                        # found place to insert. Insert and break.
                        if prev:
                            to_sort.next = curr
                            prev.next = to_sort
                        else:
                            # insert before head
                            to_sort.next = head
                            head = to_sort
                        break  # job done
                    prev = curr
                    curr = curr.next

        return head
            
head = None

node = ListNode(0)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

node = ListNode(3)
node.next = head
head = node

node = ListNode(5)
node.next = head
head = node

node = ListNode(-1)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

solution = Solution()
head_sort = solution.insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = -1
# node.val = 5
# node.val = 3
# node.val = 4
# node.val = 0
#
# sorted list:
# node.val = -1
# node.val = 0
# node.val = 3
# node.val = 4
# node.val = 5

# %% [markdown]
# ### First submission
#
# Accepted by LeetCode: Runtime: 196 ms, faster than 78.93% of Python3 online submissions for Insertion Sort List.
# Memory Usage: 15.8 MB, less than 38.62% of Python3 online submissions for Insertion Sort List.

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def insertion_sort_list(self, head):
        """
        Takes head of linked list as parameter. Sorts the linked list using head and end to keep track of sorted part.
        Returns head of sorted list.
        """
        end = head
        while end:
            to_sort = end.next
            if to_sort is None:
                return head

            if to_sort.val >= end.val:
                end = to_sort
                continue

            else:
                # end stays the same: to_sort moves down

                end.next = to_sort.next  # remove to_sort from the list

                curr = head
                prev = None
                while curr:
                    if to_sort.val < curr.val:
                        # found place to insert. Insert and break.
                        if prev:
                            to_sort.next = curr
                            prev.next = to_sort
                        else:
                            # insert before head
                            to_sort.next = head
                            head = to_sort
                        break  # job done
                    prev = curr
                    curr = curr.next

        return head
            
head = None

node = ListNode(3)
node.next = head
head = node

node = ListNode(1)
node.next = head
head = node

node = ListNode(2)
node.next = head
head = node

node = ListNode(4)
node.next = head
head = node

print("original list:")
node = head
while node:
    print(f"node.val = {node.val}")
    node = node.next

solution = Solution()
head_sort = solution.insertion_sort_list(head)

print("\nsorted list:")
node = head_sort
while node:
    print(f"node.val = {node.val}")
    node = node.next
# Out:
# original list:
# node.val = 4
# node.val = 2
# node.val = 1
# node.val = 3
#
# sorted list:
# node.val = 1
# node.val = 2
# node.val = 3
# node.val = 4

# %%
a = [4, 2, 1, 3]
print(f"a before = {a}")
a.sort()
print(f"a after = {a}")

b = [-1, 5, 3, 4, 0]
print(f"b before = {b}")
b.sort()
print(f"b after =  {b}")
# Out:
# a before = [4, 2, 1, 3]
# a after = [1, 2, 3, 4]
# b before = [-1, 5, 3, 4, 0]
# b after =  [-1, 0, 3, 4, 5]
